# %% [markdown]
# ## Analisando dataset de música MPB

# %%
import pandas as pd

# %%
url = "dadosmusicasmpb/mpb-data-set.json"
pd.read_json(url)
# Out:
#                                                  album  \
# 0                                           TECNICOLOR
# 1     ENCICLOPÉDIA MUSICAL BRASILEIRA - CARLOS CACHAÇA
# 2                                      MIRAGEM DE INAÊ
# 3                                  PAULO MOURA HEPTETO
# 4           ANTOLOGIA DA CANÇÃO BRASILEIRA - Volume 01
# ...                                                ...
# 7320                                           MOSAICO
# 7321             PERCUSSIVÉ OU A PRECE DO LOUVA-A-DEUS
# 7322                                  FESTA DOS DEUSES
# 7323                                             MARÉS
# 7324                                LUZES DA MESMA LUZ
#
#                          interpretes  \
# 0                      [Os Mutantes]
# 1                   [Carlos Cachaça]
# 2         [Anna Paes, Iara Ferreira]
# 3                      [Paulo Moura]
# 4               [Bocato, Léa Freire]
# ...                              ...
# ...

# %%
dados = pd.read_json(url)

# %%
dados.head(10)
# Out:
#                                               album  \
# 0                                        TECNICOLOR
# 1  ENCICLOPÉDIA MUSICAL BRASILEIRA - CARLOS CACHAÇA
# 2                                   MIRAGEM DE INAÊ
# 3                               PAULO MOURA HEPTETO
# 4        ANTOLOGIA DA CANÇÃO BRASILEIRA - Volume 01
# 5                                           RODOPIO
# 6                          PAULINHO DA VIOLA - 1968
# 7                           CASA DE SAMBA - VOL. 03
# 8                                       REFLECTIONS
# 9                                  O POETA APRENDIZ
#
#                                          interpretes  \
# 0                                      [Os Mutantes]
# 1                                   [Carlos Cachaça]
# 2                         [Anna Paes, Iara Ferreira]
# 3                                      [Paulo Moura]
# 4                               [Bocato, Léa Freire]
# 5                                       [Luiz Tatit]
# ...

# %%
dados.tail(10)
# Out:
#                                       album                     interpretes  \
# 7315                 BRASIL FROM THE INSIDE                   [Trio da Paz]
# 7316                   CALVO, COM SOBREPESO                  [Edson Natale]
# 7317                        CANTO DE RAINHA                    [Ivone Lara]
# 7318            DUPLAS DE BAMBAS - Disco 01   [Francisco Alves, Mário Reis]
# 7319                               PRECIOSO                        [Duofel]
# 7320                                MOSAICO                 [Angelo Primon]
# 7321  PERCUSSIVÉ OU A PRECE DO LOUVA-A-DEUS                [Felipe Azevedo]
# 7322                       FESTA DOS DEUSES               [Hermeto Pascoal]
# 7323                                  MARÉS                  [Belô Velloso]
# 7324                     LUZES DA MESMA LUZ  [Eduardo Gudin, Fátima Guedes]
#
#                                              info_album  \
# 7315  {'Característica': 'instrumental', 'Gravadora'...
# ...
